# abcccccaaaaaacccccccccccccaaacccccccccccccccccccccciii ppssssspppooooooooffffaacccc
# abcccccaaaaaacccccccccccccaacccccccccccccccccccccccciipppppppppppoooooooffffaaccccc
# abcccccaaaaaaccccccccccccccccccccccccccccccccccccccciihppppppppgggggggggfffaaaccccc
# abccccccaaacccccccccccccccccccccccaccccccccccccccccchhhhpppppphggggggggggfaaaaccccc
# abaaaccccccccccccccccccccccaccccaaacccccccccccccccccchhhhhhhhhhgggggggggcaacccccccc
# abaaccaaaccaccccccccccccccaaacccaaacaacccaaaaacccccccchhhhhhhhhgaaccccccccccccccccc
# abaaacaaacaacccccccccaaaccaaaacaaaaaaaaccaaaaaccccccccchhhhhhaaaaacccccccccccccccca
# abaaaccaaaaaccccccccccaaacaaaaaaaacaaaaccaaaaaaccccccccccaaacccaaaacccccccccccaccca
# abcccaaaaaaccccccccccaaaaaaaaaaaaacaaaaccaaaaaaccccccccccaaaccccaaaccccccccccaaaaaa
# abcccaaaaaaaacccccccaaaaaaaaaaaaaaaaaccccaaaaaacccccccccccccccccccccccccccccccaaaaa
# abcccaacaaaaaccccccaaaaaaaaaaaaaaaaaaacccccaacccccccccccccccccccccccccccccccccaaaaa

# %%
test_input = '''Sabqponm
abcryxxl
accszExk
acctuvwj
abdefghi'''

# %%
print(test_input)
# Out:
# Sabqponm
# abcryxxl
# accszExk
# acctuvwj
# abdefghi

# %%
def dijkstra(graph, start, end):
    
    distances = {}
    previous = {}
    unvisited = set()     
    for vertex in graph:
        distances[vertex] = len(graph)
        previous[vertex] = None
        unvisited.add(vertex)
    distances[start] = 0   
    
    while len(unvisited):
        minimum = len(graph)
        closest = None
        for vertex in unvisited:
            if distances[vertex] < minimum:
                closest = vertex
                minimum = distances[vertex]
        if closest == end:
            return distances[end]
        if closest == None:
            return minimum
        unvisited.remove(closest)

        for neighbour in graph[closest]:
#             if neighbour not in unvisited:
#                 continue
            if distances[closest] + 1 < distances[neighbour]:
                distances[neighbour] = distances[closest] + 1
                previous[neighbour] = closest

    return(distances, previous)

graph = {'A':['B', 'C'],
         'B':['A', 'D'],
         'C':['A', 'E'],
         'D':['C', 'E'],
         'E':['D', 'C']}

print(dijkstra(graph, 'A', 'E'))
# Out:
# 2

# %%
#part 1
grid = [list(line) for line in test_input.split()]

print(grid)
width = len(grid[0])
height = len(grid)

for i in range(height):
    for j in range(width):
        
        this = ord(grid[i][j])
        if grid[i][j] is 'S':
            start = (i, j)
            grid[i][j] = ord('a')
        elif grid[i][j] is 'E':
            end = (i, j)
            grid[i][j] = ord('z')
        else:
            grid[i][j] = ord(grid[i][j])

print(start, end)            
print(grid)

graph = {}

for i in range(height):
    for j in range(width):
        graph[(i, j)] = []
        if i + 1 <  height and grid[i][j] - grid[i + 1][j] >= -1:
            graph[(i, j)].append((i + 1, j))
        if i - 1 >= 0 and grid[i][j] - grid[i - 1][j] >= -1:
            graph[(i, j)].append((i - 1, j))            
        if j + 1 < width and grid[i][j] - grid[i][j + 1] >= -1:
            graph[(i, j)].append((i, j + 1))            
        if j - 1 >= 0 and grid[i][j] - grid[i][j - 1] >= -1:
            graph[(i, j)].append((i, j - 1))
            
#         print(grid[i][j])
#         for vertex in graph[(i, j)]:
#             print(grid[vertex[0]][vertex[1]])
#         print()

print(graph)
print(graph[start])
print(graph[end])


    
print(dijkstra(graph, start, end))
print(dijkstra(graph, end, start))
# Out:
# [['S', 'a', 'b', 'q', 'p', 'o', 'n', 'm'], ['a', 'b', 'c', 'r', 'y', 'x', 'x', 'l'], ['a', 'c', 'c', 's', 'z', 'E', 'x', 'k'], ['a', 'c', 'c', 't', 'u', 'v', 'w', 'j'], ['a', 'b', 'd', 'e', 'f', 'g', 'h', 'i']]
# (0, 0) (2, 5)
# [[97, 97, 98, 113, 112, 111, 110, 109], [97, 98, 99, 114, 121, 120, 120, 108], [97, 99, 99, 115, 122, 122, 120, 107], [97, 99, 99, 116, 117, 118, 119, 106], [97, 98, 100, 101, 102, 103, 104, 105]]
# {(0, 0): [(1, 0), (0, 1)], (0, 1): [(1, 1), (0, 2), (0, 0)], (0, 2): [(1, 2), (0, 1)], (0, 3): [(1, 3), (0, 4), (0, 2)], (0, 4): [(0, 5), (0, 3)], (0, 5): [(0, 6), (0, 4)], (0, 6): [(0, 7), (0, 5)], (0, 7): [(1, 7), (0, 6)], (1, 0): [(2, 0), (0, 0), (1, 1)], (1, 1): [(2, 1), (0, 1), (1, 2), (1, 0)], (1, 2): [(2, 2), (0, 2), (1, 1)], (1, 3): [(2, 3), (0, 3), (1, 2)], (1, 4): [(2, 4), (0, 4), (1, 5), (1, 3)], (1, 5): [(0, 5), (1, 6), (1, 4)], (1, 6): [(2, 6), (0, 6), (1, 7), (1, 5)], (1, 7): [(2, 7), (0, 7)], (2, 0): [(3, 0), (1, 0)], (2, 1): [(3, 1), (1, 1), (2, 2), (2, 0)], (2, 2): [(3, 2), (1, 2), (2, 1)], (2, 3): [(3, 3), (1, 3), (2, 2)], (2, 4): [(3, 4), (1, 4), (2, 5), (2, 3)], (2, 5): [(3, 5), (1, 5), (2, 6), (2, 4)], (2, 6): [(3, 6), (1, 6), (2, 7)], (2, 7): [(3, 7), (1, 7)], (3, 0): [(4, 0), (2, 0)], (3, 1): [(4, 1), (2, 1), (3, 2), (3, 0)], (3, 2): [(4, 2), (2, 2), (3, 1)], (3, 3): [(4, 3), (2, 3), (3, 4), (3, 2)], (3, 4): [(4, 4), (3, 5), (3, 3)], (3, 5): [(4, 5), (3, 6), (3, 4)], (3, 6): [(4, 6), (2, 6), (3, 7), (3, 5)], (3, 7): [(4, 7), (2, 7)], (4, 0): [(3, 0), (4, 1)], (4, 1): [(3, 1), (4, 0)], (4, 2): [(3, 2), (4, 3), (4, 1)], (4, 3): [(4, 4), (4, 2)], (4, 4): [(4, 5), (4, 3)], (4, 5): [(4, 6), (4, 4)], (4, 6): [(4, 7), (4, 5)], (4, 7): [(3, 7), (4, 6)]}
# [(1, 0), (0, 1)]
# [(3, 5), (1, 5), (2, 6), (2, 4)]
# 31
# 7

# %%
#part 2
grid = [list(line) for line in test_input.split()]

print(grid)
width = len(grid[0])
height = len(grid)

for i in range(height):
    for j in range(width):
        
        this = ord(grid[i][j])
        if grid[i][j] is 'S':
            start = (i, j)
            grid[i][j] = ord('a')
        elif grid[i][j] is 'E':
            end = (i, j)
            grid[i][j] = ord('z')
        else:
            grid[i][j] = ord(grid[i][j])

print(start, end)            
print(grid)

graph = {}

for i in range(height):
    for j in range(width):
        graph[(i, j)] = []
        if i + 1 <  height and grid[i][j] - grid[i + 1][j] >= -1:
            graph[(i, j)].append((i + 1, j))
        if i - 1 >= 0 and grid[i][j] - grid[i - 1][j] >= -1:
            graph[(i, j)].append((i - 1, j))            
        if j + 1 < width and grid[i][j] - grid[i][j + 1] >= -1:
            graph[(i, j)].append((i, j + 1))            
        if j - 1 >= 0 and grid[i][j] - grid[i][j - 1] >= -1:
            graph[(i, j)].append((i, j - 1))

minimum = len(graph)
for i in range(height):
    for j in range(width):
        if grid[i][j] == ord('a'):
            length = dijkstra(graph, (i, j), end)
            if length < minimum:
                minimum = length
                
print(minimum)
# Out:
# [['S', 'a', 'b', 'q', 'p', 'o', 'n', 'm'], ['a', 'b', 'c', 'r', 'y', 'x', 'x', 'l'], ['a', 'c', 'c', 's', 'z', 'E', 'x', 'k'], ['a', 'c', 'c', 't', 'u', 'v', 'w', 'j'], ['a', 'b', 'd', 'e', 'f', 'g', 'h', 'i']]
# (0, 0) (2, 5)
# [[97, 97, 98, 113, 112, 111, 110, 109], [97, 98, 99, 114, 121, 120, 120, 108], [97, 99, 99, 115, 122, 122, 120, 107], [97, 99, 99, 116, 117, 118, 119, 106], [97, 98, 100, 101, 102, 103, 104, 105]]
# 29

# %%
grid = [list(line) for line in full_input.split()]
width = len(grid[0])
height = len(grid)

for i in range(height):
    for j in range(width):        
        this = ord(grid[i][j])
        if grid[i][j] is 'S':
            start = (i, j)
            grid[i][j] = ord('a')
        elif grid[i][j] is 'E':
            end = (i, j)
            grid[i][j] = ord('z')
        else:
            grid[i][j] = ord(grid[i][j])
            
print(start, end)

graph = {}
for i in range(height):
    for j in range(width):
        graph[(i, j)] = []
        if i + 1 <  height and grid[i][j] - grid[i + 1][j] >= -1:
            graph[(i, j)].append((i + 1, j))
        if i - 1 >= 0 and grid[i][j] - grid[i - 1][j] >= -1:
            graph[(i, j)].append((i - 1, j))            
        if j + 1 < width and grid[i][j] - grid[i][j + 1] >= -1:
            graph[(i, j)].append((i, j + 1))            
        if j - 1 >= 0 and grid[i][j] - grid[i][j - 1] >= -1:
            graph[(i, j)].append((i, j - 1))


print('part 1', dijkstra(graph, start, end))

minimum = len(graph)
for i in range(height):
    for j in range(width):
        if grid[i][j] == ord('a'):
            length = dijkstra(graph, (i, j), end)
            if length < minimum:
                minimum = length
print('part 2', minimum)
# Out:
# (20, 0) (20, 58)
# part 1 408
# start
# part 2 399
