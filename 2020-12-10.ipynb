# %%
real_input = """77
10
143
46
79
97
54
116
60
91
80
132
20
154
53
14
103
31
65
110
43
38
47
120
112
87
24
95
33
104
73
22
66
137
21
109
118
63
55
124
146
148
84
86
147
125
23
85
117
71
48
136
151
130
83
56
140
9
49
113
131
133
74
37
127
34
32
106
1
78
11
72
40
96
17
64
92
102
123
126
90
105
57
99
27
70
98
111
30
50
67
2
155
5
119
8
39"""
example_input = """16
10
15
5
1
11
7
19
6
12
4
"""
long_example_input = """28
33
18
42
31
14
46
20
48
47
24
23
49
45
19
38
39
11
1
32
25
35
8
17
7
9
4
2
34
10
3"""
addapters = [0] + [int(number) for number in real_input.split()]
addapters += [max(addapters) + 3]

# %%
addapters.sort()
print(len(addapters))
print(addapters)
differences = [addapters[i] - addapters[i - 1] for i in range(1, len(addapters))]
print(differences)
print(differences.count(1), differences.count(3))
print(differences.count(1) * differences.count(3))
# Out:
# 99
# [0, 1, 2, 5, 8, 9, 10, 11, 14, 17, 20, 21, 22, 23, 24, 27, 30, 31, 32, 33, 34, 37, 38, 39, 40, 43, 46, 47, 48, 49, 50, 53, 54, 55, 56, 57, 60, 63, 64, 65, 66, 67, 70, 71, 72, 73, 74, 77, 78, 79, 80, 83, 84, 85, 86, 87, 90, 91, 92, 95, 96, 97, 98, 99, 102, 103, 104, 105, 106, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 123, 124, 125, 126, 127, 130, 131, 132, 133, 136, 137, 140, 143, 146, 147, 148, 151, 154, 155, 158]
# [1, 1, 3, 3, 1, 1, 1, 3, 3, 3, 1, 1, 1, 1, 3, 3, 1, 1, 1, 1, 3, 1, 1, 1, 3, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 3, 1, 3, 3, 3, 1, 1, 3, 3, 1, 3]
# 68 30
# 2040

# %%
first = [addapter for addapter in addapters if (addapter - 0 <= 3) and (addapter > 0)]
print(first)
first = [addapter for addapter in addapters if (addapter - 1 <= 3) and (addapter > 1)]
print(first)
first = [addapter for addapter in addapters if (addapter - 4 <= 3) and (addapter > 4)]
print(first)
# Out:
# [1]
# [4]
# [5, 6, 7]

# %%
finnished = []

def find_addapters(start, end):
    if start == end:
        finnished.append(True)
        return
    
    possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
    for possible in possibles:
        find_addapters(possible, end)

find_addapters(0, max(addapters))
print(len(finnished))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-271acc829691> in <module>
#      12         find_addapters(possible, end)
#      13
# ---> 14 find_addapters(0, max(addapters))
#      15 print(len(finnished))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#      10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
# ---> 12         find_addapters(possible, end)
#      13
#      14 find_addapters(0, max(addapters))
#
# <ipython-input-37-271acc829691> in find_addapters(start, end)
#       8         return
#       9
# ---> 10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
#      12         find_addapters(possible, end)
#
# <ipython-input-37-271acc829691> in <listcomp>(.0)
#       8         return
#       9
# ---> 10     possibles = [addapter for addapter in addapters if (addapter - start <= 3) and (addapter > start)]
#      11     for possible in possibles:
#      12         find_addapters(possible, end)
#
# KeyboardInterrupt:
