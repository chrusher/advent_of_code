# %%
import datetime

# %%
def game(starting_numbers, highest_turn=2020):

    last_spoken = {}
    turn_difference = {}
    turn = 1
    while turn <= highest_turn:
        if starting_numbers:
            spoken_number = starting_numbers.pop(0)

        elif is_new:
            spoken_number = 0
        else:
            spoken_number = turn_difference[last_turn]

#         print(turn, spoken_number)

        if spoken_number not in last_spoken:
            is_new = True
        else:
            is_new = False
            previous_spoken = last_spoken[spoken_number] 
        last_spoken[spoken_number] = turn
        if not is_new:
            turn_difference[spoken_number] = last_spoken[spoken_number] - previous_spoken
        last_turn = spoken_number    
        turn += 1
    
    return spoken_number

# %%
print([0, 3, 6], game([0, 3, 6]))
# Out:
# 1 0
# 2 3
# 3 6
# 4 0
# 5 3
# 6 3
# 7 1
# 8 0
# 9 4
# 10 0
# 11 2
# 12 0
# 13 2
# 14 2
# 15 1
# 16 8
# 17 0
# 18 5
# 19 0
# 20 2
# 21 6
# 22 18
# 23 0
# 24 4
# 25 15
# 26 0
# 27 3
# 28 21
# 29 0
# 30 3
# 31 3
# 32 1
# 33 17
# 34 0
# 35 5
# 36 17
# 37 3
# 38 6
# 39 17
# 40 3
# 41 3
# 42 1
# 43 10
# 44 0
# 45 10
# 46 2
# 47 26
# 48 0
# 49 4
# 50 25
# 51 0
# 52 3
# 53 11
# 54 0
# 55 3
# 56 3
# 57 1
# 58 15
# 59 33
# 60 0
# 61 6
# 62 23
# 63 0
# 64 3
# 65 8
# 66 49
# 67 0
# 68 4
# 69 19
# 70 0
# 71 3
# 72 7
# 73 0
# 74 3
# 75 3
# 76 1
# 77 19
# 78 8
# 79 13
# 80 0
# 81 7
# 82 9
# 83 0
# 84 3
# 85 9
# 86 3
# 87 2
# 88 41
# 89 0
# 90 6
# 91 29
# 92 0
# 93 3
# 94 7
# 95 13
# 96 16
# 97 0
# 98 5
# 99 63
# 100 0
# 101 3
# 102 8
# 103 24
# 104 0
# 105 4
# 106 37
# 107 0
# 108 3
# 109 7
# 110 15
# 111 52
# 112 0
# 113 5
# 114 15
# 115 4
# 116 10
# 117 71
# 118 0
# 119 6
# 120 29
# 121 29
# 122 1
# 123 46
# 124 0
# 125 6
# 126 6
# 127 1
# 128 5
# 129 15
# 130 15
# 131 1
# 132 4
# 133 17
# ...

# %%
start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 202))
end = datetime.datetime.now()
print(end - start)

start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 2020))
end = datetime.datetime.now()
print(end - start)

start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 20200))
end = datetime.datetime.now()
print(end - start)

start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 202000))
end = datetime.datetime.now()
print(end - start)

start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 2020000))
end = datetime.datetime.now()
print(end - start)

start = datetime.datetime.now()
print([1,0,18,10,19,6], game([1,0,18,10,19,6], 30000000))
end = datetime.datetime.now()
print(end - start)
# Out:
# [1, 0, 18, 10, 19, 6] 0
# 0:00:00.000730
# [1, 0, 18, 10, 19, 6] 441
# 0:00:00.001465
# [1, 0, 18, 10, 19, 6] 1365
# 0:00:00.008302
# [1, 0, 18, 10, 19, 6] 8660
# 0:00:00.077195
# [1, 0, 18, 10, 19, 6] 0
# 0:00:00.961340
# [1, 0, 18, 10, 19, 6] 10613991
# 0:00:16.548856

# %%
turn = 1
